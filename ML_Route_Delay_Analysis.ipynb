# %%
import statsmodels.formula.api as smf
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import scipy.stats as stats
import pylab
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import export_graphviz
import pydot


data_path = "airline_2m.csv"

#CSV Can be directly downloaded as a tar file here: 

#https://dax-cdn.cdn.appdomain.cloud/dax-airline/1.0.1/airline_2m.tar.gz?_ga=2.241493383.460169643.1645306071-17791737.1643504108

# Credit to IBM's Airline Dataset for the data and encoding code.


data = pd.read_csv(data_path, encoding = "ISO-8859-1",
                 dtype={'Div1Airport': str, 'Div1TailNum': str, 'Div2Airport': str, 'Div2TailNum': str})
#Code Provided By IBMs Airline Reporting Carrier on-time performance set. 
#This helps python better interpret the data frame because it is not encoded in UTF-8 
#An alternative to this could be to actually change the file to be encoded in UTF-8
#but this was difficult to do with how big the file was.

# %% [markdown]
# ## One-Hot Encoding Splitting Label and Features
#
# The chosen features are destination, year, time in the sky, month, airline and originating airport. The label trying to be predicted is arrival delay.

# %%
sample = data.sample(1000)

sample = sample[['Origin','Dest','ArrDelay', 'Year','AirTime','Month','Reporting_Airline']]
sample['ArrDelay'] = sample['ArrDelay'].fillna(0)
sample['AirTime'] = sample['AirTime'].fillna(0)
print(sample.columns)
features = pd.get_dummies(sample)

print(features.head())

# Labels are the values we want to predict
labels = np.array(features['ArrDelay'])
# Remove the labels from the features
# axis 1 refers to the columns
features = features.drop('ArrDelay', axis = 1)
# Saving feature names for later use
feature_list = list(features.columns)
# Convert to numpy array
features = np.array(features)
# Out:
# Index(['Origin', 'Dest', 'ArrDelay', 'Year', 'AirTime', 'Month',
#        'Reporting_Airline'],
#       dtype='object')
#          ArrDelay  Year  AirTime  Month  Origin_ABQ  Origin_AEX  Origin_AGS  \
# 811960       24.0  2017     54.0      3           0           0           0
# 1523576      -4.0  1994      0.0      8           0           0           0
# 1296041     -13.0  2004     95.0      5           0           0           0
# 431851        5.0  2009     68.0      4           0           0           0
# 513172       21.0  2000    116.0      5           0           0           0
#
#          Origin_ALB  Origin_AMA  Origin_ANC  ...  Reporting_Airline_PA (1)  \
# 811960            0           0           0  ...                         0
# 1523576           0           0           0  ...                         0
# 1296041           0           0           0  ...                         0
# 431851            0           0           0  ...                         0
# 513172            0           0           0  ...                         0
#
#          Reporting_Airline_PI  Reporting_Airline_TW  Reporting_Airline_UA  \
# 811960                      0                     0                     0
# 1523576                     0                     0                     1
# 1296041                     0                     0                     0
# 431851                      0                     0                     0
# 513172                      0                     0                     0
#
#          Reporting_Airline_US  Reporting_Airline_VX  Reporting_Airline_WN  \
# 811960                      0                     0                     0
# 1523576                     0                     0                     0
# 1296041                     0                     0                     0
# 431851                      0                     0                     1
# 513172                      0                     0                     0
#
#          Reporting_Airline_XE  Reporting_Airline_YV  Reporting_Airline_YX
# 811960                      0                     0                     0
# 1523576                     0                     0                     0
# 1296041                     0                     0                     0
# 431851                      0                     0                     0
# 513172                      0                     0                     0
#
# [5 rows x 328 columns]

# %% [markdown]
# # Splitting the Data Between Test and Train

# %%
# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 420)

print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (750, 327)
# Training Labels Shape: (750,)
# Testing Features Shape: (250, 327)
# Testing Labels Shape: (250,)

# %% [markdown]
# # Create Base Line Predictions
#
# The baseline prediction is an array of 0s representing a baseline prediction of no delay. This was chosen as 0 is the expected value of delay.

# %%
# The baseline predictions is 0
baseline_preds = np.zeros(len(test_features))
print(baseline_preds.shape)
# Baseline errors, and display average baseline error
baseline_errors = abs(baseline_preds - test_labels)
print(baseline_errors)
print('Average baseline error: ', round(np.mean(baseline_errors), 2))
# Out:
# (250,)
# [  6.  47.  15.   8.   7.   2.  10.   4.   8.   2. 117.  31.   9.  14.
#    5.  10.  14.  18.   8.  20.   0.  25.  15.  24.   4.   7.  10.   3.
#    0.  27.   3.   1.  30.  12.   4.  39.   0.  32.   7.   3. 230.   1.
#   13.   6.  13.  53.   8.   4.  40.  30.   3.   0.   2.  13.   5.  10.
#    9.  20.  12.   6.  27.   5.  45.  11. 103.  17.  21.   5.  12.   2.
#    3.   1.  41.   4.  11.  15.   5.   1.   6.   1.   7.  13.  13.  47.
#    8.   2.  10.   4.   2.   3.  10.  10.   3.   4.  21.  14.  47.   8.
#   11.  74.  12.  56.  38.  10.  12.   8.  12.  28.  21.  10.   9.  19.
#   23.   9.  10.  24.  14.   3.  89.   4.   0.   7.   3.   2.   0.  18.
#   15.   7.   3.   7.   9.   8.   0.   0.  14.  29.   3.   5.   6.   1.
#   25.  12.  14.  16.   5.   5.   2.   0.   4.  11.  31.   7.  27.  18.
#   14.   6.  12.   7.  99.   2.   3.  12.   1.  17.   5.   7.  15.   9.
#    3.  21.   3.   7.  64.   0.   5.  15.   3.  15.   0.  71.   6.   7.
#    4.   4.  15.  25.   0.   3.   1.  11.   2.   4.  15.   4.   2.   4.
#    7.   5.   4.   7.  30.   5.  15.   2.  54.  12.   9.   9.  36.   5.
#    5.  10.   3.  12.   3.  38.  46.   5.   5.  23.   7.   0.  15.   8.
#  115.   3.  21.   9.   4.  15. 105.  11.   3.  10.  26.   8.  17.   3.
#   25.   2.   7.   2.   5.   2.   8.  12.  59. 140.  10.  26.]
# Average baseline error:  16.01

# %% [markdown]
# ### Train the model

# %%
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 100, random_state = 420)
# Train the model on training data
rf.fit(train_features, train_labels);
# Use the forest's predict method on the test data

# %%
rf_new = RandomForestRegressor(n_estimators = 100, criterion = 'mse', max_depth = None, 
                               min_samples_split = 2, min_samples_leaf = 1)
rf_new.fit(train_features, train_labels);

# %% [markdown]
# ### Test the model
# Notice that the average Baseline error was lower average estimate error. This indicates that the model has issues and cannot reliably predict the label. The label chosen was Arrival delay.

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 18.95 degrees.

# %% [markdown]
# ### Generates list of the Features by importance
# Notice that flights that arrive in Minneapolis Saint Paul is the most important factor, perhaps this is because of the weather in Minnesota.

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 4)) 
                       for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: Year                 Importance: 0.0796
# Variable: AirTime              Importance: 0.071
# Variable: Month                Importance: 0.0683
# Variable: Dest_RSW             Importance: 0.0428
# Variable: Dest_LAS             Importance: 0.0422
# Variable: Origin_ORF           Importance: 0.0414
# Variable: Reporting_Airline_UA Importance: 0.0297
# Variable: Origin_SRQ           Importance: 0.0278
# Variable: Reporting_Airline_DL Importance: 0.0254
# Variable: Origin_PVD           Importance: 0.0251
# Variable: Dest_SLC             Importance: 0.0249
# Variable: Dest_LGA             Importance: 0.0213
# Variable: Dest_CMI             Importance: 0.0206
# Variable: Origin_SFO           Importance: 0.0202
# Variable: Dest_MOB             Importance: 0.019
# Variable: Origin_ALB           Importance: 0.018
# Variable: Origin_PIT           Importance: 0.0178
# Variable: Origin_EWR           Importance: 0.0175
# Variable: Origin_MDW           Importance: 0.0173
# Variable: Dest_XNA             Importance: 0.0132
# Variable: Dest_EWR             Importance: 0.0123
# Variable: Reporting_Airline_MQ Importance: 0.0119
# Variable: Reporting_Airline_WN Importance: 0.0118
# Variable: Reporting_Airline_CO Importance: 0.0113
# Variable: Origin_MKE           Importance: 0.0112
# Variable: Reporting_Airline_B6 Importance: 0.0102
# Variable: Dest_CLE             Importance: 0.0093
# Variable: Dest_MCO             Importance: 0.009
# Variable: Dest_DCA             Importance: 0.0089
# Variable: Origin_LAS           Importance: 0.0083
# Variable: Reporting_Airline_PA (1) Importance: 0.0073
# Variable: Origin_KOA           Importance: 0.0065
# Variable: Origin_JFK           Importance: 0.0064
# Variable: Dest_ATL             Importance: 0.0062
# Variable: Dest_SFO             Importance: 0.0062
# Variable: Origin_IAH           Importance: 0.006
# Variable: Dest_MCI             Importance: 0.006
# Variable: Origin_RDU           Importance: 0.0055
# Variable: Reporting_Airline_US Importance: 0.0052
# Variable: Reporting_Airline_EV Importance: 0.0051
# Variable: Origin_CLT           Importance: 0.005
# Variable: Origin_ORD           Importance: 0.005
# Variable: Dest_ORD             Importance: 0.005
# Variable: Dest_ABQ             Importance: 0.0047
# Variable: Origin_RSW           Importance: 0.0045
# Variable: Dest_LAX             Importance: 0.0044
# Variable: Origin_DTW           Importance: 0.0043
# Variable: Origin_IND           Importance: 0.0042
# Variable: Origin_MSP           Importance: 0.0042
# Variable: Dest_MEM             Importance: 0.0041
# Variable: Dest_MSN             Importance: 0.0039
# Variable: Origin_BWI           Importance: 0.0038
# Variable: Dest_BOS             Importance: 0.0037
# Variable: Dest_JFK             Importance: 0.0036
# Variable: Dest_BQK             Importance: 0.0035
# Variable: Origin_AVL           Importance: 0.0032
# Variable: Origin_LAX           Importance: 0.0032
# Variable: Origin_DEN           Importance: 0.0031
# Variable: Dest_PNS             Importance: 0.003
# Variable: Reporting_Airline_OO Importance: 0.003
# Variable: Origin_JAX           Importance: 0.0029
# Variable: Dest_BUR             Importance: 0.0029
# Variable: Dest_TPA             Importance: 0.0029
# Variable: Reporting_Airline_AA Importance: 0.0029
# Variable: Dest_CVG             Importance: 0.0027
# Variable: Origin_HOU           Importance: 0.0026
# Variable: Dest_FWA             Importance: 0.0026
# Variable: Origin_SNA           Importance: 0.0025
# Variable: Reporting_Airline_HP Importance: 0.0024
# Variable: Origin_ATL           Importance: 0.0023
# Variable: Dest_OKC             Importance: 0.0023
# Variable: Origin_LGA           Importance: 0.0022
# Variable: Dest_SAN             Importance: 0.0022
# Variable: Dest_DAY             Importance: 0.0021
# Variable: Origin_PBI           Importance: 0.002
# Variable: Origin_AVP           Importance: 0.0019
# Variable: Origin_SEA           Importance: 0.0019
# Variable: Dest_DFW             Importance: 0.0019
# Variable: Origin_DFW           Importance: 0.0018
# Variable: Origin_TPA           Importance: 0.0018
# Variable: Origin_RIC           Importance: 0.0017
# Variable: Origin_SMF           Importance: 0.0017
# Variable: Dest_BWI             Importance: 0.0017
# Variable: Origin_CLE           Importance: 0.0015
# Variable: Dest_DEN             Importance: 0.0015
# Variable: Origin_DAL           Importance: 0.0014
# Variable: Dest_IAH             Importance: 0.0014
# Variable: Dest_PHL             Importance: 0.0014
# Variable: Dest_CLT             Importance: 0.0013
# Variable: Dest_JAX             Importance: 0.0013
# Variable: Origin_BNA           Importance: 0.0012
# Variable: Origin_STL           Importance: 0.0012
# Variable: Dest_PIA             Importance: 0.0012
# Variable: Dest_TVC             Importance: 0.0012
# Variable: Origin_DCA           Importance: 0.0011
# Variable: Dest_HOU             Importance: 0.0011
# Variable: Dest_SEA             Importance: 0.0011
# Variable: Reporting_Airline_NW Importance: 0.0011
# Variable: Origin_CHA           Importance: 0.001
# Variable: Origin_PSP           Importance: 0.001
# Variable: Dest_AUS             Importance: 0.001
# Variable: Dest_BDL             Importance: 0.001
# Variable: Dest_PHX             Importance: 0.001
# Variable: Reporting_Airline_XE Importance: 0.001
# Variable: Origin_CMH           Importance: 0.0009
# Variable: Dest_DTW             Importance: 0.0009
# Variable: Dest_FLL             Importance: 0.0009
# Variable: Dest_MIA             Importance: 0.0009
# Variable: Dest_SNA             Importance: 0.0009
# Variable: Origin_PHX           Importance: 0.0008
# Variable: Origin_SAT           Importance: 0.0008
# Variable: Dest_IAD             Importance: 0.0008
# Variable: Origin_BOS           Importance: 0.0007
# Variable: Origin_MIA           Importance: 0.0007
# Variable: Dest_MDW             Importance: 0.0007
# Variable: Dest_PIT             Importance: 0.0007
# Variable: Origin_BDL           Importance: 0.0006
# Variable: Origin_IAD           Importance: 0.0006
# Variable: Origin_OAK           Importance: 0.0006
# Variable: Dest_MSP             Importance: 0.0006
# Variable: Dest_MSY             Importance: 0.0006
# Variable: Dest_STL             Importance: 0.0006
# Variable: Origin_AUS           Importance: 0.0005
# Variable: Origin_BIS           Importance: 0.0005
# Variable: Origin_BZN           Importance: 0.0005
# Variable: Origin_GRR           Importance: 0.0005
# Variable: Origin_GSP           Importance: 0.0005
# Variable: Origin_MCO           Importance: 0.0005
# Variable: Origin_MEM           Importance: 0.0005
# Variable: Origin_OGG           Importance: 0.0005
# Variable: Origin_PHL           Importance: 0.0005
# Variable: Dest_OAK             Importance: 0.0005
# Variable: Dest_RIC             Importance: 0.0005
# Variable: Reporting_Airline_AS Importance: 0.0005
# Variable: Reporting_Airline_TW Importance: 0.0005
# Variable: Origin_BQK           Importance: 0.0004
# Variable: Origin_HRL           Importance: 0.0004
# Variable: Origin_MSY           Importance: 0.0004
# Variable: Origin_SAN           Importance: 0.0004
# Variable: Origin_SHV           Importance: 0.0004
# Variable: Dest_DRO             Importance: 0.0004
# Variable: Dest_SAT             Importance: 0.0004
# Variable: Reporting_Airline_FL Importance: 0.0004
# Variable: Origin_ABQ           Importance: 0.0003
# Variable: Origin_ANC           Importance: 0.0003
# Variable: Origin_RNO           Importance: 0.0003
# Variable: Origin_SDF           Importance: 0.0003
# Variable: Origin_SLC           Importance: 0.0003
# Variable: Dest_BNA             Importance: 0.0003
# Variable: Dest_MAF             Importance: 0.0003
# Variable: Dest_SJC             Importance: 0.0003
# Variable: Dest_TUL             Importance: 0.0003
# Variable: Reporting_Airline_NK Importance: 0.0003
# Variable: Reporting_Airline_YV Importance: 0.0003
# Variable: Origin_BIL           Importance: 0.0002
# Variable: Origin_BUF           Importance: 0.0002
# Variable: Origin_CMI           Importance: 0.0002
# Variable: Origin_FSD           Importance: 0.0002
# Variable: Origin_JAN           Importance: 0.0002
# Variable: Origin_MCI           Importance: 0.0002
# Variable: Origin_OKC           Importance: 0.0002
# Variable: Origin_ONT           Importance: 0.0002
# Variable: Origin_SBN           Importance: 0.0002
# Variable: Dest_BOI             Importance: 0.0002
# Variable: Dest_BZN             Importance: 0.0002
# Variable: Dest_COS             Importance: 0.0002
# Variable: Dest_ELP             Importance: 0.0002
# Variable: Dest_GRB             Importance: 0.0002
# Variable: Dest_LEX             Importance: 0.0002
# Variable: Dest_MKE             Importance: 0.0002
# Variable: Dest_OMA             Importance: 0.0002
# Variable: Dest_PDX             Importance: 0.0002
# Variable: Dest_RDU             Importance: 0.0002
# Variable: Dest_SJU             Importance: 0.0002
# Variable: Dest_SMF             Importance: 0.0002
# Variable: Reporting_Airline_EA Importance: 0.0002
# Variable: Reporting_Airline_OH Importance: 0.0002
# Variable: Origin_CHS           Importance: 0.0001
# Variable: Origin_CVG           Importance: 0.0001
# Variable: Origin_DAY           Importance: 0.0001
# Variable: Origin_FAR           Importance: 0.0001
# Variable: Origin_FLL           Importance: 0.0001
# Variable: Origin_GEG           Importance: 0.0001
# Variable: Origin_GSO           Importance: 0.0001
# Variable: Origin_HLN           Importance: 0.0001
# Variable: Origin_LGB           Importance: 0.0001
# Variable: Origin_LIT           Importance: 0.0001
# Variable: Origin_MEI           Importance: 0.0001
# Variable: Origin_OMA           Importance: 0.0001
# Variable: Origin_PDX           Importance: 0.0001
# Variable: Origin_PNS           Importance: 0.0001
# Variable: Origin_SJC           Importance: 0.0001
# Variable: Origin_SYR           Importance: 0.0001
# Variable: Origin_TYS           Importance: 0.0001
# Variable: Origin_VPS           Importance: 0.0001
# Variable: Dest_AEX             Importance: 0.0001
# Variable: Dest_ANC             Importance: 0.0001
# Variable: Dest_BUF             Importance: 0.0001
# Variable: Dest_HNL             Importance: 0.0001
# Variable: Dest_IND             Importance: 0.0001
# Variable: Dest_JAN             Importance: 0.0001
# Variable: Dest_LRD             Importance: 0.0001
# Variable: Dest_MHT             Importance: 0.0001
# Variable: Dest_PBI             Importance: 0.0001
# Variable: Dest_PIB             Importance: 0.0001
# Variable: Dest_SDF             Importance: 0.0001
# Variable: Dest_SRQ             Importance: 0.0001
# Variable: Dest_TUS             Importance: 0.0001
# Variable: Dest_TYS             Importance: 0.0001
# Variable: Reporting_Airline_9E Importance: 0.0001
# Variable: Reporting_Airline_DH Importance: 0.0001
# Variable: Reporting_Airline_F9 Importance: 0.0001
# Variable: Reporting_Airline_VX Importance: 0.0001
# Variable: Origin_AEX           Importance: 0.0
# Variable: Origin_AGS           Importance: 0.0
# Variable: Origin_AMA           Importance: 0.0
# Variable: Origin_BGR           Importance: 0.0
# Variable: Origin_BHM           Importance: 0.0
# Variable: Origin_BLI           Importance: 0.0
# Variable: Origin_BOI           Importance: 0.0
# Variable: Origin_BTR           Importance: 0.0
# Variable: Origin_BUR           Importance: 0.0
# Variable: Origin_CAE           Importance: 0.0
# Variable: Origin_CAK           Importance: 0.0
# Variable: Origin_CLD           Importance: 0.0
# Variable: Origin_COS           Importance: 0.0
# Variable: Origin_DLH           Importance: 0.0
# Variable: Origin_DSM           Importance: 0.0
# Variable: Origin_ELP           Importance: 0.0
# Variable: Origin_EYW           Importance: 0.0
# Variable: Origin_FAI           Importance: 0.0
# Variable: Origin_FAT           Importance: 0.0
# Variable: Origin_FAY           Importance: 0.0
# Variable: Origin_FSM           Importance: 0.0
# Variable: Origin_FWA           Importance: 0.0
# Variable: Origin_GNV           Importance: 0.0
# Variable: Origin_GRK           Importance: 0.0
# Variable: Origin_HNL           Importance: 0.0
# Variable: Origin_HPN           Importance: 0.0
# Variable: Origin_ICT           Importance: 0.0
# Variable: Origin_IDA           Importance: 0.0
# Variable: Origin_ILM           Importance: 0.0
# Variable: Origin_JNU           Importance: 0.0
# Variable: Origin_LAN           Importance: 0.0
# Variable: Origin_LBB           Importance: 0.0
# Variable: Origin_LEX           Importance: 0.0
# Variable: Origin_LFT           Importance: 0.0
# Variable: Origin_LIH           Importance: 0.0
# Variable: Origin_MFE           Importance: 0.0
# Variable: Origin_MHT           Importance: 0.0
# Variable: Origin_MKG           Importance: 0.0
# Variable: Origin_MLI           Importance: 0.0
# Variable: Origin_MSN           Importance: 0.0
# Variable: Origin_MYR           Importance: 0.0
# Variable: Origin_OME           Importance: 0.0
# Variable: Origin_PSC           Importance: 0.0
# Variable: Origin_ROC           Importance: 0.0
# Variable: Origin_SAV           Importance: 0.0
# Variable: Origin_SJU           Importance: 0.0
# Variable: Origin_SMX           Importance: 0.0
# Variable: Origin_SPS           Importance: 0.0
# Variable: Origin_STT           Importance: 0.0
# Variable: Origin_STX           Importance: 0.0
# Variable: Origin_TOL           Importance: 0.0
# Variable: Origin_TUL           Importance: 0.0
# Variable: Origin_TUS           Importance: 0.0
# Variable: Origin_TWF           Importance: 0.0
# Variable: Dest_AMA             Importance: 0.0
# Variable: Dest_ASE             Importance: 0.0
# Variable: Dest_ATW             Importance: 0.0
# Variable: Dest_BGR             Importance: 0.0
# Variable: Dest_BHM             Importance: 0.0
# Variable: Dest_BIL             Importance: 0.0
# Variable: Dest_CHS             Importance: 0.0
# Variable: Dest_CID             Importance: 0.0
# Variable: Dest_CLD             Importance: 0.0
# Variable: Dest_CMH             Importance: 0.0
# Variable: Dest_CRP             Importance: 0.0
# Variable: Dest_CSG             Importance: 0.0
# Variable: Dest_CWA             Importance: 0.0
# Variable: Dest_DAL             Importance: 0.0
# Variable: Dest_DSM             Importance: 0.0
# Variable: Dest_EVV             Importance: 0.0
# Variable: Dest_EYW             Importance: 0.0
# Variable: Dest_FAR             Importance: 0.0
# Variable: Dest_FAT             Importance: 0.0
# Variable: Dest_FSD             Importance: 0.0
# Variable: Dest_GEG             Importance: 0.0
# Variable: Dest_GRR             Importance: 0.0
# Variable: Dest_GSO             Importance: 0.0
# Variable: Dest_GSP             Importance: 0.0
# Variable: Dest_GUC             Importance: 0.0
# Variable: Dest_HLN             Importance: 0.0
# Variable: Dest_HPN             Importance: 0.0
# Variable: Dest_HRL             Importance: 0.0
# Variable: Dest_HSV             Importance: 0.0
# Variable: Dest_ICT             Importance: 0.0
# Variable: Dest_IDA             Importance: 0.0
# Variable: Dest_ISO             Importance: 0.0
# Variable: Dest_ISP             Importance: 0.0
# Variable: Dest_ITO             Importance: 0.0
# Variable: Dest_KTN             Importance: 0.0
# Variable: Dest_LGB             Importance: 0.0
# Variable: Dest_LIT             Importance: 0.0
# Variable: Dest_MCN             Importance: 0.0
# Variable: Dest_MGM             Importance: 0.0
# Variable: Dest_MRY             Importance: 0.0
# Variable: Dest_MSO             Importance: 0.0
# Variable: Dest_OGG             Importance: 0.0
# Variable: Dest_ONT             Importance: 0.0
# Variable: Dest_ORF             Importance: 0.0
# Variable: Dest_OTZ             Importance: 0.0
# Variable: Dest_PSC             Importance: 0.0
# Variable: Dest_PVD             Importance: 0.0
# Variable: Dest_RNO             Importance: 0.0
# Variable: Dest_ROC             Importance: 0.0
# Variable: Dest_RST             Importance: 0.0
# Variable: Dest_SAV             Importance: 0.0
# Variable: Dest_SGF             Importance: 0.0
# Variable: Dest_STX             Importance: 0.0
# Variable: Dest_SUN             Importance: 0.0
# Variable: Dest_SYR             Importance: 0.0
# Variable: Dest_YUM             Importance: 0.0
# Variable: Reporting_Airline_HA Importance: 0.0
# Variable: Reporting_Airline_KH Importance: 0.0
# Variable: Reporting_Airline_PI Importance: 0.0
# Variable: Reporting_Airline_YX Importance: 0.0

# %%
# New random forest with only the two most important variables
rf_most_important = RandomForestRegressor(n_estimators= 1000, random_state=42)
# Extract the two most important features
important_indices = [feature_list.index('Distance'), feature_list.index('AirTime')]
train_important = train_features[:, important_indices]
test_important = test_features[:, important_indices]
# Train the random forest
rf_most_important.fit(train_important, train_labels)
# Make predictions and determine the error
predictions = rf_most_important.predict(test_important)
errors = abs(predictions - test_labels)
# Display the performance metrics
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3g/bh_v25hx11qdsybrwgz_x7fm0000gp/T/ipykernel_10354/620807541.py in <module>
#       2 rf_most_important = RandomForestRegressor(n_estimators= 1000, random_state=42)
#       3 # Extract the two most important features
# ----> 4 important_indices = [feature_list.index('Distance'), feature_list.index('AirTime')]
#       5 train_important = train_features[:, important_indices]
#       6 test_important = test_features[:, important_indices]
#
# ValueError: 'Distance' is not in list
